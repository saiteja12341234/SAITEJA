# %% [markdown]
# <a href="https://colab.research.google.com/github/saiteja12341234/SAITEJA/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#matplot
#line graph

plt.plot(data['sepal_length'])
plt.show()

# %%
plt.plot(data['sepal_width'])
plt.show()

# %%
plt.plot(data['petal_length'])
plt.show()

# %%
plt.plot(data['petal_width'])
plt.show()

# %%
plt.plot(data['petal_length'])
plt.plot(data['petal_width'])
plt.show()

# %%
plt.plot(data['petal_length'])
plt.plot(data['petal_width'])
plt.xlabel("indexes")
plt.ylabel("petal counts")
plt.title("iris petal",fontsize= 27)
plt.show()

# %%
plt.plot(data['petal_length'],label="petal_length")
plt.plot(data['petal_width'],label="petal_width")
plt.xlabel("indexes")
plt.ylabel("petal counts")
plt.title("iris petal",fontsize= 27)
plt.legend()
plt.show()

# %%
plt.plot(data['petal_length'],label = "petal length",linestyle = "--")
plt.plot(data['petal_width'],label="petal width", marker = "o")
plt.xlabel("indexes")
plt.ylabel("petal counts")
plt.title("iris petal",fontsize= 27)
plt.legend()
plt.show()

# %%
plt.plot(data['petal_length'],label = "petal length",linestyle = "--",linewidth=3)
plt.plot(data['petal_width'],label="petal width", marker = "o")
plt.xlabel("indexes")
plt.ylabel("petal counts")
plt.title("iris petal",fontsize= 27)
plt.legend()
plt.show()
